# %% [markdown]
# # AI Marketing Campaign Intelligence Walkthrough
#
# This notebook explains the analysis workflow for the GitHub portfolio project. Run the Python scripts first to generate the datasets and charts.

# %% [markdown]
# ## Business Questions
#
# - Which marketing channels generate the highest revenue and ROAS?
# - Which campaigns convert efficiently?
# - Which cities and audience segments deserve more budget?
# - What should a business manager do next?

# %%
import pandas as pd

campaigns = pd.read_csv('../data/processed/clean_campaign_data.csv')
channel = pd.read_csv('../data/processed/channel_performance.csv')
city = pd.read_csv('../data/processed/city_performance.csv')
segment = pd.read_csv('../data/processed/audience_segment_performance.csv')

campaigns.head()

# %%
channel[['channel', 'spend_aud', 'revenue_aud', 'conversions', 'roas', 'cpa_aud']]

# %% [markdown]
# ## Interpretation
#
# Retargeting and email are the strongest efficiency channels. Google Search is the strongest scalable acquisition channel. LinkedIn Ads and Influencer campaigns need stronger targeting, better creative testing, or a different measurement approach.

# %%
city[['city', 'revenue_aud', 'spend_aud', 'conversions', 'roas']]

# %% [markdown]
# ## Executive Recommendation
#
# Increase investment in retargeting, email, and Google Search. Use social, influencer, and LinkedIn campaigns for awareness and audience creation, then convert those audiences through retargeting and email journeys.
